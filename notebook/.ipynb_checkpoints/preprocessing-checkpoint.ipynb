# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator ## ImageDataGenerator → loads images in batches
import matplotlib.pyplot as plt

# %%
IMG_SIZE = (224, 224)      ## input image size  for VGG16 architecture
BATCH_SIZE = 32
##fix label for each class
label_map = {
    "NonDemented": 0,
    "VeryMildDemented": 1,
    "MildDemented": 2,
    "ModerateDemented": 3
}

# %%
# ===============================
# 2. Data Generator 
# ===============================
def get_data_generators(dataset_path):
    print("Creating data generators...\n")

    datagen = ImageDataGenerator(
        rescale=1.0 / 255,
        validation_split=0.2
    )

    train_generator = datagen.flow_from_directory(
        dataset_path,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training'
    )

    val_generator = datagen.flow_from_directory(
        dataset_path,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='validation'
    )

    print("\nClass indices:", train_generator.class_indices)
    print("\nData generators ready\n")

    return train_generator, val_generator

# %%
# ===============================
# 1. Class Distribution Function
# ===============================
def plot_class_distribution(dataset_path):
    print("Analyzing dataset...\n")

    classes = os.listdir(dataset_path)
    counts = []

    for c in classes:
        class_path = os.path.join(dataset_path, c)

        if os.path.isdir(class_path):
            num_images = len(os.listdir(class_path))
            counts.append(num_images)
            print(f"{c}: {num_images} images")

    print("\nPlotting distribution...\n")

    plt.figure(figsize=(8, 5))
    plt.bar(classes, counts)

    # show numbers on bars
    for i, v in enumerate(counts):
        plt.text(i, v + 10, str(v), ha='center')

    plt.title("MRI Dataset Class Distribution")
    plt.xlabel("Classes")
    plt.ylabel("Number of Images")
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()

# %%
DATASET_PATH = r"D:\CODE\Alzheimer_Detection_And_Classification\data\raw_mri"

# Show class distribution
plot_class_distribution(DATASET_PATH)

# Load generators
train_gen, val_gen = get_data_generators(DATASET_PATH)

# Check one batch
X_batch, y_batch = next(train_gen)

print("Batch shape:", X_batch.shape)
print("Labels shape:", y_batch.shape)
# Out:
# Analyzing dataset...
#
# MildDemented: 7178 images
# ModerateDemented: 10000 images
# NonDemented: 12800 images
# VeryMildDemented: 11200 images
#
# Plotting distribution...
# Creating data generators...
#
# Found 32943 images belonging to 4 classes.
# Found 8235 images belonging to 4 classes.
#
# Class indices: {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}
#
# Data generators ready
#
# Batch shape: (32, 224, 224, 3)
# Labels shape: (32, 4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

def show_images(X_batch, y_batch, generator):
    class_labels = list(generator.class_indices.keys())

    # ======================
    # 1. Show Images
    # ======================
    plt.figure(figsize=(10, 10))

    for i in range(len(X_batch)):
        plt.subplot(4, 8, i + 1)

        plt.imshow(X_batch[i])

        label_index = np.argmax(y_batch[i])
        plt.title(class_labels[label_index], fontsize=8)

        plt.axis("off")

    plt.suptitle("Batch Images", fontsize=14)
    plt.tight_layout()
    plt.show()

    # ======================
    # 2. Class Distribution
    # ======================
    labels = np.argmax(y_batch, axis=1)
    counts = Counter(labels)

    classes = []
    values = []

    for idx, count in counts.items():
        classes.append(class_labels[idx])
        values.append(count)

    print("\nBatch Class Distribution:\n")
    for c, v in zip(classes, values):
        print(f"{c}: {v}")

    plt.figure(figsize=(6, 4))
    plt.bar(classes, values)

    for i, v in enumerate(values):
        plt.text(i, v + 0.2, str(v), ha='center')

    plt.title("Batch Class Distribution")
    plt.xlabel("Classes")
    plt.ylabel("Count")
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()

# %%
X1,y1 = next(train_gen)
X2, y2 = next(train_gen)
show_images(X1, y1, train_gen)
# Out:
# Batch Class Distribution:
#
# NonDemented: 13
# MildDemented: 6
# VeryMildDemented: 7
# ModerateDemented: 6

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
BASE_PATH = r"D:\CODE\Alzheimer_Detection_And_Classification\data"

# %%
datagen = ImageDataGenerator(rescale=1./255)

train_gen = datagen.flow_from_directory(
    BASE_PATH + "/train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = datagen.flow_from_directory(
    BASE_PATH + "/val",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_gen = datagen.flow_from_directory(
    BASE_PATH + "/test",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("Train:", train_gen.samples)
print("Val:", val_gen.samples)
print("Test:", test_gen.samples)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 3
#       1 datagen = ImageDataGenerator(rescale=1./255)
# ----> 3 train_gen = datagen.flow_from_directory(
#       4     BASE_PATH + "/train",
#       5     target_size=IMG_SIZE,
#       6     batch_size=BATCH_SIZE,
#       7     class_mode='categorical'
#       8 )
#      10 val_gen = datagen.flow_from_directory(
#      11     BASE_PATH + "/val",
#      12     target_size=IMG_SIZE,
#      13     batch_size=BATCH_SIZE,
#      14     class_mode='categorical'
#      15 )
#      17 test_gen = datagen.flow_from_directory(
#      18     BASE_PATH + "/test",
#      19     target_size=IMG_SIZE,
#    (...)
#      22     shuffle=False
#      23 )
#
# File ~\anaconda3\envs\p_env\lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)
#    1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
#    1140         color_mode=color_mode,
#    1141         keep_aspect_ratio=keep_aspect_ratio,
#    1142         classes=classes,
#    1143         class_mode=class_mode,
#    1144         data_format=self.data_format,
#    1145         batch_size=batch_size,
#    1146         shuffle=shuffle,
#    1147         seed=seed,
#    1148         save_to_dir=save_to_dir,
#    1149         save_prefix=save_prefix,
#    1150         save_format=save_format,
#    1151         follow_links=follow_links,
#    1152         subset=subset,
#    1153         interpolation=interpolation,
#    1154         dtype=self.dtype,
#    1155     )
#
# File ~\anaconda3\envs\p_env\lib\site-packages\keras\src\legacy\preprocessing\image.py:456, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454 if not classes:
#     455     classes = []
# --> 456     for subdir in sorted(os.listdir(directory)):
#     457         if os.path.isdir(os.path.join(directory, subdir)):
#     458             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\CODE\\Alzheimer_Detection_And_Classification\\data/train'
